# %% [markdown]
# # EDA y first look
#
# 11 octubre

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
# read the data

df_entrena = pd.read_csv('data/hoteles-entrena.csv')
df_prueba = pd.read_csv('data/hoteles-prueba.csv')

# %%
# look at the data
print(df_entrena.head())
print(df_prueba.head())

#size of the data
print(df_entrena.shape)
print(df_prueba.shape)
# Out:
#           hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# 0  Resort_Hotel        342                        0                     0
# 1  Resort_Hotel        737                        0                     0
# 2  Resort_Hotel          7                        0                     1
# 3  Resort_Hotel         13                        0                     1
# 4  Resort_Hotel         14                        0                     2
#
#    adults children meal country market_segment distribution_channel  ...  \
# 0       2     none   BB     PRT         Direct               Direct  ...
# 1       2     none   BB     PRT         Direct               Direct  ...
# 2       1     none   BB     GBR         Direct               Direct  ...
# 3       1     none   BB     GBR      Corporate            Corporate  ...
# 4       2     none   BB     GBR      Online_TA                TA/TO  ...
#
#    booking_changes  deposit_type  agent company days_in_waiting_list  \
# 0                3    No_Deposit    NaN     NaN                    0
# 1                4    No_Deposit    NaN     NaN                    0
# 2                0    No_Deposit    NaN     NaN                    0
# 3                0    No_Deposit  304.0     NaN                    0
# 4                0    No_Deposit  240.0     NaN                    0
#
#    customer_type average_daily_rate  required_car_parking_spaces  \
# 0      Transient                0.0                         none
# 1      Transient                0.0                         none
# 2      Transient               75.0                         none
# 3      Transient               75.0                         none
# 4      Transient               98.0                         none
#
#    total_of_special_requests  arrival_date
# 0                          0    2015-07-01
# 1                          0    2015-07-01
# 2                          0    2015-07-01
# 3                          0    2015-07-01
# 4                          1    2015-07-01
#
# [5 rows x 25 columns]
#    id         hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# 0   1  Resort_Hotel         14                        0                     2
# 1   2  Resort_Hotel         68                        0                     4
# 2   3  Resort_Hotel         18                        0                     4
# 3   4  Resort_Hotel         68                        0                     4
# 4   5  Resort_Hotel         37                        0                     4
#
#    adults meal country market_segment distribution_channel  ...  \
# 0       2   BB     GBR      Online_TA                TA/TO  ...
# 1       2   BB     USA      Online_TA                TA/TO  ...
# 2       2   HB     ESP      Online_TA                TA/TO  ...
# 3       2   BB     IRL      Online_TA                TA/TO  ...
# 4       2   BB     PRT  Offline_TA/TO                TA/TO  ...
#
#    booking_changes  deposit_type  agent company days_in_waiting_list  \
# 0                0    No_Deposit  240.0     NaN                    0
# 1                0    No_Deposit  240.0     NaN                    0
# 2                1    No_Deposit  241.0     NaN                    0
# 3                0    No_Deposit  240.0     NaN                    0
# 4                0    No_Deposit    8.0     NaN                    0
#
#    customer_type average_daily_rate  required_car_parking_spaces  \
# 0      Transient              98.00                         none
# 1      Transient              97.00                         none
# 2      Transient             154.77                         none
# 3      Transient              97.00                         none
# 4       Contract              97.50                         none
#
#    total_of_special_requests  arrival_date
# 0                          1    2015-07-01
# 1                          3    2015-07-01
# 2                          1    2015-07-01
# 3                          3    2015-07-01
# 4                          0    2015-07-01
#
# [5 rows x 25 columns]
# (52981, 25)
# (22185, 25)

# %%
# check for missing values
print(df_entrena.isnull().sum())
print(df_prueba.isnull().sum())
# Out:
# hotel                                 0
# lead_time                             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# meal                                  0
# country                             300
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                              8643
# company                           49042
# days_in_waiting_list                  0
# customer_type                         0
# average_daily_rate                    0
# required_car_parking_spaces           0
# total_of_special_requests             0
# arrival_date                          0
# dtype: int64
# id                                    0
# hotel                                 0
# lead_time                             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# meal                                  0
# country                             121
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                              3667
# company                           20518
# days_in_waiting_list                  0
# customer_type                         0
# average_daily_rate                    0
# required_car_parking_spaces           0
# total_of_special_requests             0
# arrival_date                          0
# dtype: int64
# 7218
